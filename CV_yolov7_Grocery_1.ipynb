# %% [markdown]
# This code snipit is part of my work with a local startup. I am sharing it only as a showcase for my postdoc application. Please make sure not to share it with anyone else.

# %% [markdown]
# # **Preperation**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python --version
# Out:
# Python 3.7.14

# %% [markdown]
# https://neptune.ai/blog/mlops-pipeline-for-computer-vision-image-classification

# %%
# %ls
# %pwd
# Out:
# drive/  sample_data/
# '/content'

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %cd drive/MyDrive/ProdutDetection/yolov7/
# %ls
# Out:
# /content/drive/MyDrive/ProdutDetection/yolov7
# yolov7/  yolov7_custom/  yolov7_grocery/  yolov7_grocery_deployment/

# %% [markdown]
# Clone repo

# %%
# !git clone https://github.com/WongKinYiu/yolov7.git
# %cd yolov7
# %ls

# %%
# %ls
# Out:
# yolov7/  yolov7_custom/  yolov7_grocery/  yolov7_grocery_deployment/

# %%
# %cd yolov7_grocery/
# %ls
# Out:
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery
# 'result_compressed (1).mp4'   result_compressed.mp4   yolov7/

# %%
# %cd yolov7/
# %ls
# Out:
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery/yolov7
# 20220824_135814.mp4  hubconf.py    README.md              traced_model.pt
# 20220824_140204.mp4  inference/    requirements_GPU.txt   train_aux.py
# cfg/                 LICENSE.md    requirements.txt       train.py
# data/                models/       result_compressed.mp4  utils/
# deploy/              output_2.mp4  runs/                  yolov7.pt
# detect.py            output.mp4    scripts/
# export.py            paper/        test.py
# figure/              __pycache__/  tools/

# %%
# %cd data
# %ls
# Out:
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery/yolov7/data
# coco.yaml                  grocery_roboflow/
# CV_yolov7_Grocery_1.ipynb  hyp.scratch.custom.yaml
# grocery/                   hyp.scratch.p5.yaml
# Grocery_Images_1/          hyp.scratch.p6.yaml
# Grocery_Images_1.zip       hyp.scratch.tiny.yaml
# grocery_images_2/          linux_commandLine_commands.txt

# %% [markdown]
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery/yolov7/data

# %%
# %cd grocery_roboflow/
# %ls
# Out:
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery/yolov7/data/grocery_roboflow
# Grocery_2-5/

# %% [markdown]
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery/yolov7/data/grocery_roboflow/Grocery_2-5

# %%
# import pandas as pd 
# import os
# import tqdm

# from sklearn.model_selection import train_test_split

# def split_img_label(data_train,data_test,folder_train,folder_test):
    
#     os.mkdir(folder_train)
#     os.mkdir(folder_test)
    
    
#     train_ind=list(data_train.index)
#     test_ind=list(data_test.index)
    
    
#     # Train folder
#     for i in tqdm(range(len(train_ind))):
        
#         os.system('cp '+data_train[train_ind[i]]+' ./'+ folder_train + '/'  +data_train[train_ind[i]].split('/')[2])
#         os.system('cp '+data_train[train_ind[i]].split('.jpg')[0]+'.txt'+'  ./'+ folder_train + '/'  +data_train[train_ind[i]].split('/')[2].split('.jpg')[0]+'.txt')
    
#     # Test folder
#     for j in tqdm(range(len(test_ind))):
        
#         os.system('cp '+data_test[test_ind[j]]+' ./'+ folder_test + '/'  +data_test[test_ind[j]].split('/')[2])
#         os.system('cp '+data_test[test_ind[j]].split('.jpg')[0]+'.txt'+'  ./'+ folder_test + '/'  +data_test[test_ind[j]].split('/')[2].split('.jpg')[0]+'.txt')

# %%
# PATH_IMAGES = './images/'
# PATH_LABELS = './labels/'
# list_img=[img for img in os.listdir(PATH_IMAGES) if img.endswith('.jpg')==True]
# list_txt=[img for img in os.listdir(PATH_LABELS) if img.endswith('.txt')==True]

# %%
# from google.colab import files
# files.upload()

# %% [markdown]
# # **Get the new custom data**

# %%
# !pip install simple_image_download==0.4

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="z5mpLbQOTanAWxjuMwPH")
# project = rf.workspace("anas321-gbtjh").project("grocery_2")
# dataset = project.version(5).download("yolov7")

# %%
# %cd Grocery_2-5/
# %ls
# Out:
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery/yolov7/data/grocery_roboflow/Grocery_2-5
# data.yaml  README.dataset.txt  README.roboflow.txt  test/  train/  valid/

# %%
# %ls train/images/ | wc -l
# %ls train/images/ | wc -l
# %ls valid/images/ | wc -l
# %ls valid/labels/ | wc -l
# %ls test/images/  | wc -l
# %ls test/labels/  | wc -l
# Out:
# 530
# 530
# 43
# 43
# 17
# 17

# %%
# !du -sh train/images/
# !du -sh train/labels/
# !du -sh valid/images/
# !du -sh valid/labels/
# !du -sh test/images/
# !du -sh test/labels/
# Out:
# 12M	train/images/
# 1.1M	valid/images/
# 382K	test/images/

# %%
# %cd train/images/
# %ls | head -10
# %cd ../../
# Out:
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery/yolov7/data/grocery_roboflow/Grocery_2-5/train/images
# 20220819_175723_jpg.rf.5a4455a03387b6b2df10e7bd4d68422e.jpg
# 20220819_175723_jpg.rf.5cbd8afb09cf2d4e2facd522431df8aa.jpg
# 20220819_175723_jpg.rf.86a8ed182fb2e931b0648c3e7902c71c.jpg
# 20220819_175726_jpg.rf.3108b4b7e545729e33a3467623d178cc.jpg
# 20220819_175726_jpg.rf.7877388df020f0565f4260067cc81161.jpg
# 20220819_175726_jpg.rf.86b3377f41e9d2ab2d1de267076c1933.jpg
# 20220819_175729_jpg.rf.14571aa553585978a63434715ce191af.jpg
# 20220819_175729_jpg.rf.7dd021d8868470d7c573944bd5acadc3.jpg
# 20220819_175729_jpg.rf.7f314c05e7c8e50ddec3c25fa3c20dbb.jpg
# 20220819_175732_jpg.rf.4953f5bcd31c85a452e78d10d8f62b03.jpg
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery/yolov7/data/grocery_roboflow/Grocery_2-5

# %%
from PIL import Image

image_name = 'train/images/20220819_175732_jpg.rf.4953f5bcd31c85a452e78d10d8f62b03.jpg'
im = Image.open(image_name)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416 at 0x7F840DF8C690>

# %%
im.size
# Out:
# (416, 416)

# %%
import os
print(os.stat(image_name).st_size,'bytes')
# Out:
# 22631 bytes

# %%
# %cd ../../../
# %ls
# Out:
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery/yolov7
# 20220824_135814.mp4  hubconf.py    README.md              traced_model.pt
# 20220824_140204.mp4  inference/    requirements_GPU.txt   train_aux.py
# cfg/                 LICENSE.md    requirements.txt       train.py
# data/                models/       result_compressed.mp4  utils/
# deploy/              output_2.mp4  runs/                  yolov7.pt
# detect.py            output.mp4    scripts/
# export.py            paper/        test.py
# figure/              __pycache__/  tools/

# %% [markdown]
# # **Modify files to account for the new custom data**

# %% [markdown]
# Files to modify:
# 1) data/coco_custom.yaml
# 2) cfg/training/yolov7_custom.yaml
#
# and place the train and val folders into data folder

# %%
# %cd Trash-5/
# %ls

# %%
# grocery_roboflow/Grocery_2-5/train

# %%
# %cd ../../../cfg/training/
# %ls

# %%
# %cp yolov7_custom.yaml trashData.yaml
# %ls

# %%
# %cd ../../
# %ls

# %%
# %ls
# Out:
# 20220824_135814.mp4  hubconf.py    README.md              traced_model.pt
# 20220824_140204.mp4  inference/    requirements_GPU.txt   train_aux.py
# cfg/                 LICENSE.md    requirements.txt       train.py
# data/                models/       result_compressed.mp4  utils/
# deploy/              output_2.mp4  runs/                  yolov7.pt
# detect.py            output.mp4    scripts/
# export.py            paper/        test.py
# figure/              __pycache__/  tools/

# %% [markdown]
# # **Get Yolov7 weights**

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt

# %%
# %ls
# Out:
# 20220824_135814.mp4  hubconf.py    README.md              traced_model.pt
# 20220824_140204.mp4  inference/    requirements_GPU.txt   train_aux.py
# cfg/                 LICENSE.md    requirements.txt       train.py
# data/                models/       result_compressed.mp4  utils/
# deploy/              output_2.mp4  runs/                  yolov7.pt
# detect.py            output.mp4    scripts/
# export.py            paper/        test.py
# figure/              __pycache__/  tools/

# %% [markdown]
# # **Check for GPU classifications**

# %%
# This cell ensures you have the correct architecture for your respective GPU
# If you command is not found, look through these GPUs, find the respective
# GPU and add them to the archTypes dictionary

# Tesla V100
# ARCH= -gencode arch=compute_70,code=[sm_70,compute_70]

# Tesla K80 
# ARCH= -gencode arch=compute_37,code=sm_37

# GeForce RTX 2080 Ti, RTX 2080, RTX 2070, Quadro RTX 8000, Quadro RTX 6000, Quadro RTX 5000, Tesla T4, XNOR Tensor Cores
# ARCH= -gencode arch=compute_75,code=[sm_75,compute_75]

# Jetson XAVIER
# ARCH= -gencode arch=compute_72,code=[sm_72,compute_72]

# GTX 1080, GTX 1070, GTX 1060, GTX 1050, GTX 1030, Titan Xp, Tesla P40, Tesla P4
# ARCH= -gencode arch=compute_61,code=sm_61

# GP100/Tesla P100 - DGX-1
# ARCH= -gencode arch=compute_60,code=sm_60

# For Jetson TX1, Tegra X1, DRIVE CX, DRIVE PX - uncomment:
# ARCH= -gencode arch=compute_53,code=[sm_53,compute_53]

# For Jetson Tx2 or Drive-PX2 uncomment:
# ARCH= -gencode arch=compute_62,code=[sm_62,compute_62]
import os
os.environ['GPU_TYPE'] = str(os.popen('nvidia-smi --query-gpu=name --format=csv,noheader').read())

def getGPUArch(argument):
  try:
    argument = argument.strip()
    # All Colab GPUs
    archTypes = {
        "Tesla V100-SXM2-16GB": "-gencode arch=compute_70,code=[sm_70,compute_70]",
        "Tesla K80": "-gencode arch=compute_37,code=sm_37",
        "Tesla T4": "-gencode arch=compute_75,code=[sm_75,compute_75]",
        "Tesla P40": "-gencode arch=compute_61,code=sm_61",
        "Tesla P4": "-gencode arch=compute_61,code=sm_61",
        "Tesla P100-PCIE-16GB": "-gencode arch=compute_60,code=sm_60"
      }
    return archTypes[argument]
  except KeyError:
    return "GPU must be added to GPU Commands"
os.environ['ARCH_VALUE'] = getGPUArch(os.environ['GPU_TYPE'])

print("GPU Type: " + os.environ['GPU_TYPE'])
print("ARCH Value: " + os.environ['ARCH_VALUE'])
# Out:
# GPU Type: Tesla P100-PCIE-16GB
#
# ARCH Value: -gencode arch=compute_60,code=sm_60

# %%
# !nvidia-smi
# Out:
# Mon Sep 12 10:28:15 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # **Install requirments**

# %%
# %ls
# Out:
# 20220824_135814.mp4  hubconf.py    README.md              traced_model.pt
# 20220824_140204.mp4  inference/    requirements_GPU.txt   train_aux.py
# cfg/                 LICENSE.md    requirements.txt       train.py
# data/                models/       result_compressed.mp4  utils/
# deploy/              output_2.mp4  runs/                  yolov7.pt
# detect.py            output.mp4    scripts/
# export.py            paper/        test.py
# figure/              __pycache__/  tools/

# %% [markdown]
# Modify the requirments.txt file

# %%
# !cp requirements_GPU.txt requirements_GPU_Pro.txt
# %ls
# Out:
# 20220824_135814.mp4  hubconf.py    requirements_GPU_Pro.txt  traced_model.pt
# 20220824_140204.mp4  inference/    requirements_GPU.txt      train_aux.py
# cfg/                 LICENSE.md    requirements.txt          train.py
# data/                models/       result_compressed.mp4     utils/
# deploy/              output.mp4    runs/                     yolov7.pt
# detect.py            paper/        scripts/
# export.py            __pycache__/  test.py
# figure/              README.md     tools/

# %% [markdown]
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery/yolov7

# %%
# !pip install -r requirements.txt
# !pip install -r requirements_GPU.txt
# %ls

# %% [markdown]
# # **Train the model**

# %% [markdown]
# **REMEMBER TO DELETE .cache FILES BEFORE TRAINING**
#
# cache files directories
#
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery/yolov7/data/grocery_roboflow/Grocery_2-5/train
#
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery/yolov7/data/grocery_roboflow/Grocery_2-5/valid

# %%
im.size
# Out:
# (416, 416)

# %%
im.size[0]/32, im.size[1]/32
# Out:
# (13.0, 13.0)

# %%
# train p5 models
# 32*80 = 2560 = number of cores in Tesla T4 GPU
# 32*50 = 1600
# 32*40 = 1280
# 32*30 = 960
# ------------------------------------
# DELETE .cache FILES BEFORE TRAINING
# ------------------------------------
# !python train.py \
--workers 8 --device 0 \
--batch-size 16 --epochs 100 \
--data data/grocery_roboflow/Grocery_2-5/data.yaml \
--img-size 640 640 \
--cfg cfg/training/yolov7.yaml \
--weights 'yolov7.pt' \
--name yolov7_grocery_2_results \
--hyp data/hyp.scratch.p5.yaml \
# --resume runs/train/yolov7_trash20/weights/last.pt
# Out:
# YOLOR 🚀 v0.1-105-g064c71e torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7.yaml', data='data/grocery_roboflow/Grocery_2-5/data.yaml', device='0', entity=None, epochs=100, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.p5.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7_grocery_2_results', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov7_grocery_2_results2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, weights='yolov7.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
ls
# Out:
# 20220824_135814.mp4  hubconf.py    README.md              traced_model.pt
# 20220824_140204.mp4  inference/    requirements_GPU.txt   train_aux.py
# cfg/                 LICENSE.md    requirements.txt       train.py
# data/                models/       result_compressed.mp4  utils/
# deploy/              output_2.mp4  runs/                  yolov7.pt
# detect.py            output.mp4    scripts/
# export.py            paper/        test.py
# figure/              __pycache__/  tools/

# %%
# %cd runs/train/
# %ls
# Out:
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery/yolov7/runs/train
# yolov7_grocery_2_results/  yolov7_grocery_2_results2/

# %%
# %ls -l
# Out:
# total 8
# drwx------ 2 root root 4096 Aug 23 19:38 yolov7_grocery_2_results/
# drwx------ 2 root root 4096 Aug 23 19:40 yolov7_grocery_2_results2/

# %%
# %ls yolov7_grocery_2_results/
# Out:
# events.out.tfevents.1661283536.90c71092d748.577.0  hyp.yaml  opt.yaml  weights/

# %%
# %ls yolov7_grocery_2_results/weights/

# %%
# %ls yolov7_grocery_2_results2/
# Out:
# confusion_matrix.png                                test_batch1_pred.jpg
# events.out.tfevents.1661283648.90c71092d748.1721.0  train_batch0.jpg
# F1_curve.png                                        train_batch1.jpg
# hyp.yaml                                            train_batch2.jpg
# opt.yaml                                            train_batch3.jpg
# P_curve.png                                         train_batch4.jpg
# PR_curve.png                                        train_batch5.jpg
# R_curve.png                                         train_batch6.jpg
# results.png                                         train_batch7.jpg
# results.txt                                         train_batch8.jpg
# test_batch0_labels.jpg                              train_batch9.jpg
# test_batch0_pred.jpg                                weights/
# test_batch1_labels.jpg

# %%
# %ls yolov7_grocery_2_results2/weights/
# Out:
# best.pt       epoch_024.pt  epoch_074.pt  epoch_096.pt  epoch_098.pt  init.pt
# epoch_000.pt  epoch_049.pt  epoch_095.pt  epoch_097.pt  epoch_099.pt  last.pt

# %%
# from PIL import Image

# %%
# Image.open('F1_curve.png')
# Image.open('PR_curve.png')
# Image.open('confusion_matrix.png')

# %%
# from IPython.display import Image

# %%
# display(Image('F1_curve.png'))
# display(Image('PR_curve.png'))
# display(Image('confusion_matrix.png'))

# %%
# %cd ../../
# %ls
# Out:
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery/yolov7
# 20220824_135814.mp4  hubconf.py    README.md              traced_model.pt
# 20220824_140204.mp4  inference/    requirements_GPU.txt   train_aux.py
# cfg/                 LICENSE.md    requirements.txt       train.py
# data/                models/       result_compressed.mp4  utils/
# deploy/              output_2.mp4  runs/                  yolov7.pt
# detect.py            output.mp4    scripts/
# export.py            paper/        test.py
# figure/              __pycache__/  tools/

# %% [markdown]
# # **Inference on Test Images**

# %%
# %ls runs/train/yolov7_grocery_2_results2/weights/
# Out:
# best.pt       epoch_024.pt  epoch_074.pt  epoch_096.pt  epoch_098.pt  init.pt
# epoch_000.pt  epoch_049.pt  epoch_095.pt  epoch_097.pt  epoch_099.pt  last.pt

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery/yolov7'

# %%
# !python detect.py \
--weights runs/train/yolov7_grocery_2_results2/weights/best.pt \
--conf 0.1 \
--source data/grocery_roboflow/Grocery_2-5/test/images \
--exist-ok
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.1, device='', exist_ok=True, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='data/grocery_roboflow/Grocery_2-5/test/images', update=False, view_img=False, weights=['runs/train/yolov7_grocery_2_results2/weights/best.pt'])
# YOLOR 🚀 v0.1-105-g064c71e torch 1.12.1+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36568076 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
# ...

# %%
ls
# Out:
# 20220824_135814.mp4  hubconf.py    README.md              traced_model.pt
# 20220824_140204.mp4  inference/    requirements_GPU.txt   train_aux.py
# cfg/                 LICENSE.md    requirements.txt       train.py
# data/                models/       result_compressed.mp4  utils/
# deploy/              output_2.mp4  runs/                  yolov7.pt
# detect.py            output.mp4    scripts/
# export.py            paper/        test.py
# figure/              __pycache__/  tools/

# %%
import glob
from IPython.display import Image, display

i = 0
limit = 10 # max images to print
for imageName in glob.glob('runs/detect/exp/*.jpg'):
    #Assuming JPG
    if i < limit:
      display(Image(filename=imageName))
      print("\n")
    i = i + 1

# %% [markdown]
# # **Inference on Custom Test Images**

# %%
import os
import sys

sys.path.append('/content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery/yolov7')


import argparse
import time
from pathlib import Path
import cv2
import torch
import numpy as np
import torch.backends.cudnn as cudnn
from numpy import random

from models.experimental import attempt_load
from utils.datasets import LoadStreams, LoadImages
from utils.general import check_img_size, check_requirements, check_imshow, \
    non_max_suppression, apply_classifier, \
    scale_coords, xyxy2xywh, strip_optimizer, set_logging, increment_path
from utils.plots import plot_one_box
from utils.torch_utils import select_device, load_classifier, time_synchronized, TracedModel


def letterbox(img, new_shape=(640, 640), color=(114, 114, 114), auto=True, scaleFill=False, scaleup=True, stride=32):
    # Resize and pad image while meeting stride-multiple constraints
    shape = img.shape[:2]  # current shape [height, width]
    if isinstance(new_shape, int):
        new_shape = (new_shape, new_shape)

    # Scale ratio (new / old)
    r = min(new_shape[0] / shape[0], new_shape[1] / shape[1])
    if not scaleup:  # only scale down, do not scale up (for better test mAP)
        r = min(r, 1.0)

    # Compute padding
    ratio = r, r  # width, height ratios
    new_unpad = int(round(shape[1] * r)), int(round(shape[0] * r))
    dw, dh = new_shape[1] - new_unpad[0], new_shape[0] - new_unpad[1]  # wh padding
    if auto:  # minimum rectangle
        dw, dh = np.mod(dw, stride), np.mod(dh, stride)  # wh padding
    elif scaleFill:  # stretch
        dw, dh = 0.0, 0.0
        new_unpad = (new_shape[1], new_shape[0])
        ratio = new_shape[1] / shape[1], new_shape[0] / shape[0]  # width, height ratios

    dw /= 2  # divide padding into 2 sides
    dh /= 2

    if shape[::-1] != new_unpad:  # resize
        img = cv2.resize(img, new_unpad, interpolation=cv2.INTER_LINEAR)
    top, bottom = int(round(dh - 0.1)), int(round(dh + 0.1))
    left, right = int(round(dw - 0.1)), int(round(dw + 0.1))
    img = cv2.copyMakeBorder(img, top, bottom, left, right, cv2.BORDER_CONSTANT, value=color)  # add border
    return img, ratio, (dw, dh)

# %%
classes_to_filter = None  #You can give list of classes to filter by name, Be happy you don't have to put class number. ['train','person' ]


opt  = {
    
    "weights": "runs/train/yolov7_grocery_2_results2/weights/best.pt", # Path to weights file default weights are for nano model
    "yaml"   : "data/grocery_roboflow/Grocery_2-5/data.yaml",
    "img-size": 640, # default image size
    "conf-thres": 0.25, # confidence threshold for inference.
    "iou-thres" : 0.45, # NMS IoU threshold for inference.
    "device" : '0',  # device to run our model i.e. 0 or 0,1,2,3 or cpu
    "classes" : classes_to_filter  # list of classes to filter or None
}

# %%
# !gdown https://drive.google.com/uc?id=1c96hId8WNsOASKHcAxsQeM4N-N2wuwy9
# #This does not work in Safari Browser
# %ls

# %%
# !pip install torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch
import torchvision

source_image_path = 'trash.jpg'

with torch.no_grad():
  weights, imgsz = opt['weights'], opt['img-size']
  set_logging()
  device = select_device(opt['device'])
  half = device.type != 'cpu'
  model = attempt_load(weights, map_location=device)  # load FP32 model
  stride = int(model.stride.max())  # model stride
  imgsz = check_img_size(imgsz, s=stride)  # check img_size
  if half:
    model.half()

  names = model.module.names if hasattr(model, 'module') else model.names
  colors = [[random.randint(0, 255) for _ in range(3)] for _ in names]
  if device.type != 'cpu':
    model(torch.zeros(1, 3, imgsz, imgsz).to(device).type_as(next(model.parameters())))

  img0 = cv2.imread(source_image_path)
  img = letterbox(img0, imgsz, stride=stride)[0]
  img = img[:, :, ::-1].transpose(2, 0, 1)  # BGR to RGB, to 3x416x416
  img = np.ascontiguousarray(img)
  img = torch.from_numpy(img).to(device)
  img = img.half() if half else img.float()  # uint8 to fp16/32
  img /= 255.0  # 0 - 255 to 0.0 - 1.0
  if img.ndimension() == 3:
    img = img.unsqueeze(0)
  
  # Inference
  t1 = time_synchronized()
  pred = model(img, augment= False)[0]

  # Apply NMS
  classes = None
  if opt['classes']:
    classes = []
    for class_name in opt['classes']:

      classes.append(opt['classes'].index(class_name))


  pred = non_max_suppression(pred, opt['conf-thres'], opt['iou-thres'], classes= classes, agnostic= False)
  t2 = time_synchronized()
  for i, det in enumerate(pred):
    s = ''
    s += '%gx%g ' % img.shape[2:]  # print string
    gn = torch.tensor(img0.shape)[[1, 0, 1, 0]]
    if len(det):
      det[:, :4] = scale_coords(img.shape[2:], det[:, :4], img0.shape).round()

      for c in det[:, -1].unique():
        n = (det[:, -1] == c).sum()  # detections per class
        s += f"{n} {names[int(c)]}{'s' * (n > 1)}, "  # add to string
    
      for *xyxy, conf, cls in reversed(det):

        label = f'{names[int(cls)]} {conf:.2f}'
        plot_one_box(xyxy, img0, label=label, color=colors[int(cls)], line_thickness=3)
# Out:
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-a5f9a0074bc3> in <module>
#      21
#      22   img0 = cv2.imread(source_image_path)
# ---> 23   img = letterbox(img0, imgsz, stride=stride)[0]
#      24   img = img[:, :, ::-1].transpose(2, 0, 1)  # BGR to RGB, to 3x416x416
#      25   img = np.ascontiguousarray(img)
#
# <ipython-input-57-1a6b0831b0bb> in letterbox(img, new_shape, color, auto, scaleFill, scaleup, stride)
#      25 def letterbox(img, new_shape=(640, 640), color=(114, 114, 114), auto=True, scaleFill=False, scaleup=True, stride=32):
#      26     # Resize and pad image while meeting stride-multiple constraints
# ---> 27     shape = img.shape[:2]  # current shape [height, width]
#      28     if isinstance(new_shape, int):
# ...

# %%
from google.colab.patches import cv2_imshow
# cv2_imshow(img0)

# %% [markdown]
# # **Inference on Video**

# %%
# !gdown https://drive.google.com/uc?id=1csuLHWkDf6yPm-q3z2K3ZAd6WOfKc0vy
# #! wget PUBLIC_URL_TO_MP4/AVI_FILE
# %ls

# %%
ls
# Out:
# 20220824_135814.mp4  hubconf.py    README.md              traced_model.pt
# 20220824_140204.mp4  inference/    requirements_GPU.txt   train_aux.py
# cfg/                 LICENSE.md    requirements.txt       train.py
# data/                models/       result_compressed.mp4  utils/
# deploy/              output_2.mp4  runs/                  yolov7.pt
# detect.py            output.mp4    scripts/
# export.py            paper/        test.py
# figure/              __pycache__/  tools/

# %%
# video_path = '20220824_135814.mp4'
video_path = '20220824_140204.mp4'

# Initializing video object
video = cv2.VideoCapture(video_path)


#Video information
fps = video.get(cv2.CAP_PROP_FPS)
w = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
nframes = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

# Initialzing object for writing video output
output = cv2.VideoWriter('output_2.mp4', cv2.VideoWriter_fourcc(*'DIVX'),fps , (w,h))
torch.cuda.empty_cache()
# Initializing model and setting it for inference
with torch.no_grad():
  weights, imgsz = opt['weights'], opt['img-size']
  set_logging()
  device = select_device(opt['device'])
  half = device.type != 'cpu'
  model = attempt_load(weights, map_location=device)  # load FP32 model
  stride = int(model.stride.max())  # model stride
  imgsz = check_img_size(imgsz, s=stride)  # check img_size
  if half:
    model.half()

  names = model.module.names if hasattr(model, 'module') else model.names
  colors = [[random.randint(0, 255) for _ in range(3)] for _ in names]
  if device.type != 'cpu':
    model(torch.zeros(1, 3, imgsz, imgsz).to(device).type_as(next(model.parameters())))

  classes = None
  if opt['classes']:
    classes = []
    for class_name in opt['classes']:
      classes.append(opt['classes'].index(class_name))

  for j in range(nframes):

      ret, img0 = video.read()
      if ret:
        img = letterbox(img0, imgsz, stride=stride)[0]
        img = img[:, :, ::-1].transpose(2, 0, 1)  # BGR to RGB, to 3x416x416
        img = np.ascontiguousarray(img)
        img = torch.from_numpy(img).to(device)
        img = img.half() if half else img.float()  # uint8 to fp16/32
        img /= 255.0  # 0 - 255 to 0.0 - 1.0
        if img.ndimension() == 3:
          img = img.unsqueeze(0)

        # Inference
        t1 = time_synchronized()
        pred = model(img, augment= False)[0]

        
        pred = non_max_suppression(pred, opt['conf-thres'], opt['iou-thres'], classes= classes, agnostic= False)
        t2 = time_synchronized()
        for i, det in enumerate(pred):
          s = ''
          s += '%gx%g ' % img.shape[2:]  # print string
          gn = torch.tensor(img0.shape)[[1, 0, 1, 0]]
          if len(det):
            det[:, :4] = scale_coords(img.shape[2:], det[:, :4], img0.shape).round()

            for c in det[:, -1].unique():
              n = (det[:, -1] == c).sum()  # detections per class
              s += f"{n} {names[int(c)]}{'s' * (n > 1)}, "  # add to string
    
            for *xyxy, conf, cls in reversed(det):

              label = f'{names[int(cls)]} {conf:.2f}'
              plot_one_box(xyxy, img0, label=label, color=colors[int(cls)], line_thickness=3)
        
        print(f"{j+1}/{nframes} frames processed")
        output.write(img0)
      else:
        break
    

output.release()
video.release()
# Out:
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# 1/803 frames processed
# 2/803 frames processed
# 3/803 frames processed
# 4/803 frames processed
# 5/803 frames processed
# 6/803 frames processed
# 7/803 frames processed
# 8/803 frames processed
# 9/803 frames processed
# 10/803 frames processed
# 11/803 frames processed
# 12/803 frames processed
# 13/803 frames processed
# 14/803 frames processed
# 15/803 frames processed
# 16/803 frames processed
# 17/803 frames processed
# 18/803 frames processed
# 19/803 frames processed
# 20/803 frames processed
# 21/803 frames processed
# 22/803 frames processed
# 23/803 frames processed
# 24/803 frames processed
# 25/803 frames processed
# 26/803 frames processed
# 27/803 frames processed
# 28/803 frames processed
# 29/803 frames processed
# 30/803 frames processed
# 31/803 frames processed
# 32/803 frames processed
# 33/803 frames processed
# 34/803 frames processed
# ...

# %%
# %ls
# Out:
# 20220824_135814.mp4  hubconf.py    README.md              traced_model.pt
# 20220824_140204.mp4  inference/    requirements_GPU.txt   train_aux.py
# cfg/                 LICENSE.md    requirements.txt       train.py
# data/                models/       result_compressed.mp4  utils/
# deploy/              output_2.mp4  runs/                  yolov7.pt
# detect.py            output.mp4    scripts/
# export.py            paper/        test.py
# figure/              __pycache__/  tools/

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = 'output.mp4'

# Compressed video path
compressed_path = "result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %%
# %ls
# Out:
# 20220824_135814.mp4  hubconf.py    README.md              traced_model.pt
# 20220824_140204.mp4  inference/    requirements_GPU.txt   train_aux.py
# cfg/                 LICENSE.md    requirements.txt       train.py
# data/                models/       result_compressed.mp4  utils/
# deploy/              output_2.mp4  runs/                  yolov7.pt
# detect.py            output.mp4    scripts/
# export.py            paper/        test.py
# figure/              __pycache__/  tools/

# %%
#C:\ProductDetection\yolov7\trash_project

# %%
from google.colab import files
# save_path = 'output.mp4'
save_path = 'result_compressed.mp4'
files.download(save_path)

# %% [markdown]
# # **Inference on Webcam**

# %%
# import dependencies
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from google.colab.patches import cv2_imshow
from base64 import b64decode, b64encode
import PIL
import io
import html
# function to convert the JavaScript object into an OpenCV image
def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# function to convert OpenCV Rectangle bounding box image into base64 byte string to be overlayed on video stream
def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')
  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes


# JavaScript to properly create our live video stream using our webcam as input
def video_stream():
  js = Javascript('''
    var video;
    var div = null;
    var stream;
    var captureCanvas;
    var imgElement;
    var labelElement;
    
    var pendingResolve = null;
    var shutdown = false;
    
    function removeDom() {
       stream.getVideoTracks()[0].stop();
       video.remove();
       div.remove();
       video = null;
       div = null;
       stream = null;
       imgElement = null;
       captureCanvas = null;
       labelElement = null;
    }

    function onAnimationFrame() {
      if (!shutdown) {
        window.requestAnimationFrame(onAnimationFrame);
      }
      if (pendingResolve) {
        var result = "";
        if (!shutdown) {
          captureCanvas.getContext('2d').drawImage(video, 0, 0, 640, 480);
          result = captureCanvas.toDataURL('image/jpeg', 0.8)
        }
        var lp = pendingResolve;
        pendingResolve = null;
        lp(result);
      }
    }

    async function createDom() {
      if (div !== null) {
        return stream;
      }

      div = document.createElement('div');
      div.style.border = '2px solid black';
      div.style.padding = '3px';
      div.style.width = '100%';
      div.style.maxWidth = '600px';
      document.body.appendChild(div);
      
      const modelOut = document.createElement('div');
      modelOut.innerHTML = "<span>Status:</span>";
      labelElement = document.createElement('span');
      labelElement.innerText = 'No data';
      labelElement.style.fontWeight = 'bold';
      modelOut.appendChild(labelElement);
      div.appendChild(modelOut);
           
      video = document.createElement('video');
      video.style.display = 'block';
      video.width = div.clientWidth - 6;
      video.setAttribute('playsinline', '');
      video.onclick = () => { shutdown = true; };
      stream = await navigator.mediaDevices.getUserMedia(
          {video: { facingMode: "environment"}});
      div.appendChild(video);

      imgElement = document.createElement('img');
      imgElement.style.position = 'absolute';
      imgElement.style.zIndex = 1;
      imgElement.onclick = () => { shutdown = true; };
      div.appendChild(imgElement);
      
      const instruction = document.createElement('div');
      instruction.innerHTML = 
          '<span style="color: red; font-weight: bold;">' +
          'When finished, click here or on the video to stop this demo</span>';
      div.appendChild(instruction);
      instruction.onclick = () => { shutdown = true; };
      
      video.srcObject = stream;
      await video.play();

      captureCanvas = document.createElement('canvas');
      captureCanvas.width = 640; //video.videoWidth;
      captureCanvas.height = 480; //video.videoHeight;
      window.requestAnimationFrame(onAnimationFrame);
      
      return stream;
      }
    async function stream_frame(label, imgData) {
      if (shutdown) {
        removeDom();
        shutdown = false;
        return '';
      }

      var preCreate = Date.now();
      stream = await createDom();
      
      var preShow = Date.now();
      if (label != "") {
        labelElement.innerHTML = label;
      }
            
      if (imgData != "") {
        var videoRect = video.getClientRects()[0];
        imgElement.style.top = videoRect.top + "px";
        imgElement.style.left = videoRect.left + "px";
        imgElement.style.width = videoRect.width + "px";
        imgElement.style.height = videoRect.height + "px";
        imgElement.src = imgData;
      }

      var preCapture = Date.now();
      var result = await new Promise(function(resolve, reject) {
        pendingResolve = resolve;
      });
      shutdown = false;
      
      return {'create': preShow - preCreate, 
              'show': preCapture - preShow, 
              'capture': Date.now() - preCapture,
              'img': result};
    }
    ''')

  display(js)
  
def video_frame(label, bbox):
  data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
  return data

# %%
pwd
# Out:
# '/content/drive/MyDrive/ProdutDetection/yolov7/yolov7_grocery/yolov7'

# %%
ls
# Out:
# 20220824_135814.mp4  hubconf.py    README.md              traced_model.pt
# 20220824_140204.mp4  inference/    requirements_GPU.txt   train_aux.py
# cfg/                 LICENSE.md    requirements.txt       train.py
# data/                models/       result_compressed.mp4  utils/
# deploy/              output_2.mp4  runs/                  yolov7.pt
# detect.py            output.mp4    scripts/
# export.py            paper/        test.py
# figure/              __pycache__/  tools/

# %%
# start streaming video from webcam
video_stream()
# label for video
label_html = 'Capturing...'
# initialze bounding box to empty
bbox = ''
count = 0 

with torch.no_grad():
  weights, imgsz = opt['weights'], (480,640)
  set_logging()
  device = select_device(opt['device'])
  half = device.type != 'cpu'
  model = attempt_load(weights, map_location=device)  # load FP32 model
  stride = int(model.stride.max())  # model stride

  if half:
    model.half()

  names = model.module.names if hasattr(model, 'module') else model.names
  colors = [[random.randint(0, 255) for _ in range(3)] for _ in names]
  if device.type != 'cpu':
    model(torch.zeros(1, 3, imgsz[0], imgsz[1]).to(device).type_as(next(model.parameters())))
  classes = None
  if opt['classes']:
    classes = []
    for class_name in opt['classes']:
      classes.append(opt['classes'].index(class_name))
  
  while True:
    js_reply = video_frame(label_html, bbox)
    if not js_reply:
        break

    img0 = js_to_image(js_reply["img"])
    bbox_array = np.zeros([480,640,4], dtype=np.uint8)
    img = letterbox(img0, imgsz, stride=stride)[0]
    img = img[:, :, ::-1].transpose(2, 0, 1)  # BGR to RGB, to 3x416x416
    img = np.ascontiguousarray(img)
    img = torch.from_numpy(img).to(device)
    img = img.half() if half else img.float()  # uint8 to fp16/32
    img /= 255.0  # 0 - 255 to 0.0 - 1.0
    if img.ndimension() == 3:
      img = img.unsqueeze(0)

    # Inference
    t1 = time_synchronized()
    pred = model(img, augment= False)[0]

    # Apply NMS
    pred = non_max_suppression(pred, opt['conf-thres'], opt['iou-thres'], classes= classes, agnostic= False)
    t2 = time_synchronized()

    for i, det in enumerate(pred):
      s = ''
      s += '%gx%g ' % img.shape[2:]  # print string
      gn = torch.tensor(img0.shape)[[1, 0, 1, 0]]
      if len(det):
        det[:, :4] = scale_coords(img.shape[2:], det[:, :4], img0.shape).round()

        for c in det[:, -1].unique():
          n = (det[:, -1] == c).sum()  # detections per class
          s += f"{n} {names[int(c)]}{'s' * (n > 1)}, "  # add to string
    
        for *xyxy, conf, cls in reversed(det):

          label = f'{names[int(cls)]} {conf:.2f}'
          plot_one_box(xyxy, bbox_array, label=label, color=colors[int(cls)], line_thickness=3)
    
    bbox_array[:,:,3] = (bbox_array.max(axis = 2) > 0 ).astype(int) * 255
    bbox_bytes = bbox_to_bytes(bbox_array)
    
    bbox = bbox_bytes
# Out:
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse

# %%
# classes_to_filter = None  #You can give list of classes to filter by name, Be happy you don't have to put class number. ['train','person' ]


# opt  = {
    
#     "weights": "runs/train/yolov7_grocery_2_results2/weights/best.pt", # Path to weights file default weights are for nano model
#     "yaml"   : "data/grocery_roboflow/Grocery_2-5/data.yaml",
#     "img-size": 640, # default image size
#     "conf-thres": 0.25, # confidence threshold for inference.
#     "iou-thres" : 0.45, # NMS IoU threshold for inference.
#     "device" : '0',  # device to run our model i.e. 0 or 0,1,2,3 or cpu
#     "classes" : classes_to_filter  # list of classes to filter or None
# }

# %%
# %ls
# Out:
# 1.png       inference/             requirements_GPU.txt   traced_model.pt
# cfg/        LICENSE.md             requirements.txt       train_aux.py
# data/       models/                result_compressed.mp4  train.py
# deploy/     output.mp4             runs/                  trash.jpg
# detect.py   paper/                 sample_video.mp4       utils/
# export.py   __pycache__/           scripts/               yolov7_custom.pt
# figure/     README.md              test.py                yolov7.pt
# hubconf.py  requirements_copy.txt  tools/                 yolov7-tiny.pt

# %% [markdown]
# # **Get new weights after training**

# %%
# %cd /content/drive/MyDrive/ProdutDetection/yolov7/yolov7/runs/train/yolov7_trash
# %ls
# Out:
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7/runs/train/yolov7_trash
# events.out.tfevents.1660468807.937f29c88b78.1249.0  opt.yaml
# hyp.yaml                                            weights/

# %%
# %cd weights
# %ls
# Out:
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7/runs/train/yolov7_custom/weights
# best.pt       epoch_024.pt  epoch_074.pt  epoch_096.pt  epoch_098.pt  init.pt
# epoch_000.pt  epoch_049.pt  epoch_095.pt  epoch_097.pt  epoch_099.pt  last.pt

# %%
pwd
# Out:
# '/content/drive/MyDrive/ProdutDetection/yolov7/yolov7/runs/train/yolov7_custom/weights'

# %%
# %cp best.pt ../../../../
# %ls ../../../../
# Out:
# best.pt    figure/     __pycache__/           scripts/      yolov7.pt
# cfg/       hubconf.py  README.md              test.py       yolov7-tiny.pt
# data/      inference/  requirements_copy.txt  tools/
# deploy/    LICENSE.md  requirements_GPU.txt   train_aux.py
# detect.py  models/     requirements.txt       train.py
# export.py  paper/      runs/                  utils/

# %%
# %cd ../../../../
# %mv best.pt yolov7_custom.pt
# %ls
# Out:
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7
# cfg/        inference/             requirements_GPU.txt  train.py
# data/       LICENSE.md             requirements.txt      utils/
# deploy/     models/                runs/                 yolov7_custom.pt
# detect.py   paper/                 scripts/              yolov7.pt
# export.py   __pycache__/           test.py               yolov7-tiny.pt
# figure/     README.md              tools/
# hubconf.py  requirements_copy.txt  train_aux.py

# %%
# %cd data/val/
# %ls
# Out:
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7/data/val
# images/  labels/  labels.cache

# %% [markdown]
# # **Test results**

# %%
# %cd images
# %ls
# Out:
# /content/drive/MyDrive/ProdutDetection/yolov7/yolov7/data/val/images
# 'jack sparrow_77.png'  'jack sparrow_85.png'      'Johnny depp jack_5.png'
# 'jack sparrow_79.png'  'Johnny depp jack_14.png'  'Johnny depp jack_6.png'
# 'jack sparrow_80.png'  'Johnny depp jack_15.png'  'Johnny depp jack_7.png'
# 'jack sparrow_83.png'  'Johnny depp jack_16.png'  'Johnny depp jack_8.png'
# 'jack sparrow_84.png'  'Johnny depp jack_17.png'  'Johnny depp jack_9.png'

# %%
# %ls
# Out:
#  cfg/                       LICENSE.md              scripts/
#  data/                      models/                 test.py
#  deploy/                    paper/                  tools/
#  detect.py                  __pycache__/            train_aux.py
#  export.py                  README.md               train.py
#  figure/                    requirements_copy.txt   utils/
#  hubconf.py                 requirements_GPU.txt    yolov7_custom.pt
#  inference/                 requirements.txt        yolov7.pt
# 'Johnny depp jack_14.png'   runs/                   yolov7-tiny.pt

# %%
from matplotlib import pyplot

# %%
# pyplot.imshow('1.png')

# %%
# %ls
# Out:
# 1.png      figure/     __pycache__/           scripts/      yolov7_custom.pt
# cfg/       hubconf.py  README.md              test.py       yolov7.pt
# data/      inference/  requirements_copy.txt  tools/        yolov7-tiny.pt
# deploy/    LICENSE.md  requirements_GPU.txt   train_aux.py
# detect.py  models/     requirements.txt       train.py
# export.py  paper/      runs/                  utils/

# %%
# !python detect.py --weights yolov7_custom.pt --conf 0.5 \
--img-size 640 --source 1.png --view-img --no-trace
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=True, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='1.png', update=False, view_img=True, weights=['yolov7_custom.pt'])
# YOLOR 🚀 v0.1-98-g3708cde torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients, 103.2 GFLOPS
# Done. (28.9ms) Inference, (0.4ms) NMS
# qt.qpa.xcb: could not connect to display
# ...
